# %%
import pandas as pd
import csv
import json
import re
import aiohttp
import asyncio
import google.generativeai as genai
import time

# %%
'''
- Multiple API Keys are being used to enhance performance by circumventing the rate limit of Gemini's API.
- Each API key has a rate limit of 10 requests per minute. By rotating between multiple keys, we can make more requests in a given time period.
- This ensures that our system can continue processing efficiently without hitting the rate limit too frequently.
- You can still use only 1 API key for both Gemini and YouTube each if you handle the rate limiting and rotation accordingly.
- While the system is optimized for multiple Gemini API keys, it will also function with a single API key for both YouTube and Gemini, though you may encounter rate limiting if the volume of requests is high.
'''
gemini_api = 'your_gemini_api'
gemini_api_2 = 'optional_gemini_api'
gemini_api_3 = 'optional_gemini_api'
gemini_api_4 = 'optional_gemini_api'
gemini_api_5 = 'optional_gemini_api'
youtube_api = 'your_youtube_api'
youtube_api_2 = 'optional_youtube_api'
youtube_api_3 = 'optional_youtube_api'
BASE_URL = "https://www.googleapis.com/youtube/v3"

# %%
async def fetch_videos(region_code, category_id, max_results=10, sort_by='relevance'):
    url = (f"{BASE_URL}/videos?chart=mostPopular&regionCode={region_code}"
           f"&videoCategoryId={category_id}&key={youtube_api}&maxResults={max_results}&order={sort_by}")
    async with aiohttp.ClientSession() as session:
        async with session.get(url) as response:
            if response.status == 200:
                return await response.json()
            return None

# %%
async def fetch_videos_pagination(region_code, category_id, max_results=50, sort_by='viewCount', total_results=100):
    all_videos = []
    next_page_token = None
    total_pages = total_results // max_results
    for page in range(total_pages):
        url = (f"{BASE_URL}/videos?chart=mostPopular&regionCode={region_code}"
               f"&videoCategoryId={category_id}&key={youtube_api}&maxResults={max_results}&order={sort_by}")
        if next_page_token:
            url += f"&pageToken={next_page_token}"
        async with aiohttp.ClientSession() as session:
            async with session.get(url) as response:
                if response.status == 200:
                    data = await response.json()
                    if 'items' in data:
                        all_videos.extend(data['items'])
                    next_page_token = data.get('nextPageToken')
                    if not next_page_token:
                        break
                else:
                    print(f"Error fetching page {page + 1}: {response.status}")
                    break
    return all_videos

# %%
async def fetch_videos_channel(channel_id, max_results=10, sort_by='date'):
    url = (f"{BASE_URL}/search?part=snippet&channelId={channel_id}&type=video"
           f"&maxResults={max_results}&order={sort_by}&key={youtube_api}")
    async with aiohttp.ClientSession() as session:
        async with session.get(url) as response:
            if response.status == 200:
                return await response.json()
            return None

# %%
async def fetch_videos_channel_pag(channel_id, max_results=100, sort_by='date', total_videos=100):
    url = (f"{BASE_URL}/search?part=snippet&channelId={channel_id}&type=video"
           f"&maxResults={max_results}&order={sort_by}&key={youtube_api}")
    videos = []
    next_page_token = None
    async with aiohttp.ClientSession() as session:
        while len(videos) < total_videos:
            paginated_url = url + (f"&pageToken={next_page_token}" if next_page_token else "")
            async with session.get(paginated_url) as response:
                if response.status == 200:
                    data = await response.json()
                    videos.extend(data.get('items', []))
                    next_page_token = data.get('nextPageToken')
                    if not next_page_token:
                        break
                else:
                    print(f"Failed to fetch videos. Status: {response.status}")
                    break
    return videos

# %%
async def fetch_video_details(video_id):
    video_details_url = f"{BASE_URL}/videos?part=snippet,statistics,contentDetails&id={video_id}&key={youtube_api}"
    async with aiohttp.ClientSession() as session:
        async with session.get(video_details_url) as response:
            if response.status == 200:
                result = await response.json()
                if result["items"]:
                    video_details = result["items"][0]
                    comment_count = video_details["statistics"].get("commentCount", 0)
                    if int(comment_count) > 0:
                        return video_details
            return None

# %%
async def fetch_comments_data(video_id, api, max_results, order='relevance'):
    url = f"{BASE_URL}/commentThreads?part=snippet&videoId={video_id}&key={api}&maxResults={max_results}&order={order}"
    async with aiohttp.ClientSession() as session:
        async with session.get(url) as response:
            if response.status == 200:
                return await response.json()
            return None

# %%
videos = await fetch_videos_channel('UC8butISFwT-Wl7EV0hUK0BQ', sort_by='relevance')
videos
# Out:
# {'kind': 'youtube#searchListResponse',
#  'etag': 't6Rru_HSr7DWHHiWlenLqMMp_Pg',
#  'nextPageToken': 'CAoQAA',
#  'regionCode': 'US',
#  'pageInfo': {'totalResults': 454727, 'resultsPerPage': 10},
#  'items': [{'kind': 'youtube#searchResult',
#    'etag': 'dd6zDS5gG7qH7IKYgGpQmKzVCsg',
#    'id': {'kind': 'youtube#video', 'videoId': 'VrSJhTGMM90'},
#    'snippet': {'publishedAt': '2023-03-14T16:33:52Z',
#     'channelId': 'UC8butISFwT-Wl7EV0hUK0BQ',
#     'title': 'What is Python used for?',
#     'description': 'Learn Python with this course: https://www.youtube.com/watch?v=eWRfhZUzrAc.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/VrSJhTGMM90/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/VrSJhTGMM90/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/VrSJhTGMM90/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'freeCodeCamp.org',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-03-14T16:33:52Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '9NSWhw2QYLDB3ktYAsKOCSecurE',
#    'id': {'kind': 'youtube#video', 'videoId': 'SIj4pzF0uk8'},
#    'snippet': {'publishedAt': '2023-03-07T14:37:39Z',
#     'channelId': 'UC8butISFwT-Wl7EV0hUK0BQ',
#     'title': 'A Day in the Life of freeCodeCamp U.S. Staff (A rare in-person meeting)',
#     'description': 'This was not a normal day. :) Music: 8-Bit March by Twin Musicom is licensed under a Creative Commons Attribution 4.0 license.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/SIj4pzF0uk8/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/SIj4pzF0uk8/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/SIj4pzF0uk8/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'freeCodeCamp.org',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-03-07T14:37:39Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'bHLJ2JHGsfeUvL2q3X6C3tkbwqw',
#    'id': {'kind': 'youtube#video', 'videoId': 'YY2ZhUQZyE4'},
#    'snippet': {'publishedAt': '2023-03-01T15:53:31Z',
#     'channelId': 'UC8butISFwT-Wl7EV0hUK0BQ',
#     'title': 'Why Node and React?',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/YY2ZhUQZyE4/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/YY2ZhUQZyE4/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/YY2ZhUQZyE4/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'freeCodeCamp.org',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-03-01T15:53:31Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'uiemGLQ4yL3AEaoVP5l8dK4LFRg',
#    'id': {'kind': 'youtube#video', 'videoId': 'WYLjcXpxFOQ'},
#    'snippet': {'publishedAt': '2023-02-09T14:16:24Z',
#     'channelId': 'UC8butISFwT-Wl7EV0hUK0BQ',
#     'title': 'How do loops work in Python?',
#     'description': 'Watch the full Python course: https://www.youtube.com/watch?v=eWRfhZUzrAc.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/WYLjcXpxFOQ/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/WYLjcXpxFOQ/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/WYLjcXpxFOQ/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'freeCodeCamp.org',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-02-09T14:16:24Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '3RMsRv97ldckw0i2qRnP2DYrDDI',
#    'id': {'kind': 'youtube#video', 'videoId': '8IOHjh3VQMU'},
#    'snippet': {'publishedAt': '2023-01-24T17:11:22Z',
#     'channelId': 'UC8butISFwT-Wl7EV0hUK0BQ',
#     'title': 'Webhooks Explained with a Roadtrip #shorts',
#     'description': 'Watch the full course: https://www.youtube.com/watch?v=41NOoEz3Tzc.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/8IOHjh3VQMU/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/8IOHjh3VQMU/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/8IOHjh3VQMU/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'freeCodeCamp.org',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-01-24T17:11:22Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '3-52nbe4aIfgEPCwMK69wm-xNAo',
#    'id': {'kind': 'youtube#video', 'videoId': '1hG0i9dQXeg'},
#    'snippet': {'publishedAt': '2023-02-03T16:37:12Z',
#     'channelId': 'UC8butISFwT-Wl7EV0hUK0BQ',
#     'title': 'Passwords in HTML #shorts',
#     'description': 'Learn more about HTML with this crash course: https://www.youtube.com/watch?v=916GWv2Qs08.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/1hG0i9dQXeg/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/1hG0i9dQXeg/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/1hG0i9dQXeg/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'freeCodeCamp.org',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-02-03T16:37:12Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '5MDplai0gjQagJB79L_ZdjLXwQY',
#    'id': {'kind': 'youtube#video', 'videoId': 'zcCYuF9lQUM'},
#    'snippet': {'publishedAt': '2018-05-29T14:30:02Z',
#     'channelId': 'UC8butISFwT-Wl7EV0hUK0BQ',
#     'title': 'GDPR: What it means and compliance',
#     'description': 'Learn about the components of General Data Protection Regulation (GDPR) and how they can be implemented in a small team of ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/zcCYuF9lQUM/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/zcCYuF9lQUM/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/zcCYuF9lQUM/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'freeCodeCamp.org',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2018-05-29T14:30:02Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '3WlbwYlx3DLpLWwLwreZ0zofpoQ',
#    'id': {'kind': 'youtube#video', 'videoId': 'ABlaMXkUwzY'},
#    'snippet': {'publishedAt': '2018-11-01T19:45:00Z',
#     'channelId': 'UC8butISFwT-Wl7EV0hUK0BQ',
#     'title': 'Debugging JavaScript - Are you doing it wrong?',
#     'description': 'Learn a better way to debug your JavaScript. Video from WellPaidGeek. Check out his channel: ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/ABlaMXkUwzY/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/ABlaMXkUwzY/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/ABlaMXkUwzY/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'freeCodeCamp.org',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2018-11-01T19:45:00Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '0LcPO7VnjjvxEHfcxYP4O3P2ETQ',
#    'id': {'kind': 'youtube#video', 'videoId': 'tN6oJu2DqCM'},
#    'snippet': {'publishedAt': '2024-03-11T14:16:38Z',
#     'channelId': 'UC8butISFwT-Wl7EV0hUK0BQ',
#     'title': 'Back End Developer Roadmap 2024',
#     'description': 'Learn what technologies you should learn first to become a back end web developer. Watch the full learning back end learning ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/tN6oJu2DqCM/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/tN6oJu2DqCM/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/tN6oJu2DqCM/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'freeCodeCamp.org',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2024-03-11T14:16:38Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'rjUTQtV46wo1nfX5M1FlPD1XchI',
#    'id': {'kind': 'youtube#video', 'videoId': 'nYXVvK-Wmn0'},
#    'snippet': {'publishedAt': '2025-02-06T15:15:19Z',
#     'channelId': 'UC8butISFwT-Wl7EV0hUK0BQ',
#     'title': 'AI Engineer Roadmap – How to Learn AI in 2025',
#     'description': 'This comprehensive AI Engineering roadmap will walk you through the essential skills and techniques every aspiring AI Engineer ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/nYXVvK-Wmn0/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/nYXVvK-Wmn0/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/nYXVvK-Wmn0/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'freeCodeCamp.org',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2025-02-06T15:15:19Z'}}]}

# %%
toggle = 0
async def analyze_comments(title, comments):
    if not comments or not isinstance(comments, list):
        print("Invalid or empty comments list provided.")
        return None

    prompt = f'''
    You are a sentiment analysis model specialized in news and politics-related content. Your task is to classify the sentiment of each YouTube comment in the following list as "positive", "neutral", or "negative". These are YouTube comments on news or political videos, so consider the tone, emotions, slang, and language commonly used in discussions about current events, opinions, and political issues.

    Only provide the sentiment labels as a list in the **exact same order** as the input comments. Each sentiment should align with how well the comment relates to the video's title, topic, or political stance presented.

    Video Title: "{title}"

    Sentiment classification rules:
    - "Positive": The comment supports, agrees with, or positively aligns with the video title, topic, or political stance presented in the video (e.g., "Great analysis," "This is spot on," "I totally agree").
    - "Negative": The comment disagrees with, criticizes, or negatively aligns with the video title, topic, or political stance presented in the video (e.g., "This is biased," "Completely wrong," "Terrible take").
    - "Neutral": The comment neither supports nor disagrees with the title or content, asks questions, provides unrelated feedback, or is ambiguous (e.g., "What happened next?" "I don't understand this," "Why is this even news?").

    Each comment is numbered for clarity. Follow the exact numbering in the output.
    Input format (comments):
    {comments}

    Response format should be exactly like the following (horizontal format):
    ["Positive", "Neutral", "Negative", ...]

    Not like the following (vertical format):
    ["Positive",
     "Neutral",
     "Negative",
     ...
    ]
    '''
    # In this case, we're rotating between 5 different API keys.
    '''
    Note:
    - This system works with multiple API keys to avoid hitting rate limits imposed by Gemini.
    - If you wish to use just one API key, the toggle system will still work as long as you handle the API key rotation properly.
      In that case, simply use a single API key from the list and you won't need to rotate.
    '''
    global toggle
    api_keys = [gemini_api, gemini_api_2, gemini_api_4, gemini_api_5, gemini_api_3]
    api_key = api_keys[toggle % 5]
    toggle += 1

    genai.configure(api_key=api_key)
    model = genai.GenerativeModel(model_name="gemini-2.0-flash-exp")
    # print(f'using api: {api_key}')
    try:
        response = model.generate_content(prompt)
        if response and response.text:
            raw_output = response.text.strip()
            try:
                sentiment_label = re.search(r'\[.*\]', raw_output)
                # print(sentiment_label)
                if sentiment_label:
                    sentiment_labels = json.loads(sentiment_label.group(0))
                else:
                    print(raw_output)
                    print("No sentiment labels found in the response.")
                    return None
                if len(sentiment_labels) == len(comments):
                    print(f'Number of comments Analyzed: {len(comments)}')
                    return sentiment_labels
                else:
                    print(f"Mismatch between number of comments and sentiments. len of comments: {len(comments)}, len of labels: {len(sentiment_labels)}\nRaw output: {raw_output}\n senti label: {sentiment_labels}")
                    return None
            except json.JSONDecodeError as e:
                print(f"Error decoding JSON response: {e}\nRaw output: {raw_output}")
                return None
        else:
            print("Empty or invalid response from Gemini.")
            return None

    except Exception as e:
        print(f"Error during sentiment analysis: {e}")
        return None

# %%
vid = await fetch_comments_data('R4v_7hh4Yys', youtube_api, 25)

# %%
vid
# Out:
# {'kind': 'youtube#commentThreadListResponse',
#  'etag': 'tm-uLe9IqW1OzWMMtcetGiba7zU',
#  'nextPageToken': '...',
#  'pageInfo': {'totalResults': 25, 'resultsPerPage': 25},
#  'items': [{'kind': 'youtube#commentThread',
#    'etag': 'QS_mhMGjZvNbyMq4iSEWpm9yTYM',
#    'id': 'Ugw6fWSLOwC7bCW4rGN4AaABAg',
#    'snippet': {'channelId': 'UC8butISFwT-Wl7EV0hUK0BQ',
#     'videoId': 'R4v_7hh4Yys',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'oUdR2-l9FSNYrC_HH0qiLjN0j-w',
#      'id': 'Ugw6fWSLOwC7bCW4rGN4AaABAg',
#      'snippet': {'channelId': 'UC8butISFwT-Wl7EV0hUK0BQ',
#       'videoId': 'R4v_7hh4Yys',
#       'textDisplay': 'Good luck on creating your website!',
#       'textOriginal': 'Good luck on creating your website!',
#       'authorDisplayName': '@beau',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/EI8MfxzWYhKSQYSEPRgIuiWKvvncqeA3s3FwSqrFXG9HlUfZX-lwV8GrCh9mufI_Py4nNVF5=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@beau',
#       'authorChannelId': {'value': 'UCIuFRHmDktSjlHex7Hahcug'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 51,
#       'publishedAt': '2025-01-21T15:02:05Z',
#       'updatedAt': '2025-01-21T15:02:05Z'}},
#     'canReply': True,
#     'totalReplyCount': 4,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'F8op_Gp6LSdYWhXAqLB1BOMhNdw',
#    'id': 'UgzLTXkk9eMrwT-HWMZ4AaABAg',
#    'snippet': {'channelId': 'UC8butISFwT-Wl7EV0hUK0BQ',
#     'videoId': 'R4v_7hh4Yys',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '3_lUR-5iRGFvHcSQWKv4oTfhI3s',
#      'id': 'UgzLTXkk9eMrwT-HWMZ4AaABAg',
#      'snippet': {'channelId': 'UC8butISFwT-Wl7EV0hUK0BQ',
#       'videoId': 'R4v_7hh4Yys',
#       'textDisplay': 'Man you&#39;re actually reading my mind 😊',
#       'textOriginal': "Man you're actually reading my mind 😊",
#       'authorDisplayName': '@abdul-soburademoye5626',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_kT_WVkUr873TeHLXwgzfHa2ErWbd64k34qZTPRPNT9BaM=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@abdul-soburademoye5626',
#       'authorChannelId': {'value': 'UCAdLJE_xikvHYy1CF6tdaxg'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 10,
#       'publishedAt': '2025-01-21T15:20:07Z',
#       'updatedAt': '2025-01-21T15:20:07Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'xKff8SiDgvoF6xTtlN4KBvFqYtY',
#    'id': 'Ugxzu_yoQ8DFizxpG3V4AaABAg',
#    'snippet': {'channelId': 'UC8butISFwT-Wl7EV0hUK0BQ',
#     'videoId': 'R4v_7hh4Yys',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'yZ-WEQZEttVXLas3U5OpRZyj0G0',
#      'id': 'Ugxzu_yoQ8DFizxpG3V4AaABAg',
#      'snippet': {'channelId': 'UC8butISFwT-Wl7EV0hUK0BQ',
#       'videoId': 'R4v_7hh4Yys',
#       'textDisplay': 'Thank you for the (for me) update. Understanding which site does what has helped me a lot!<br>It&#39;s been nice to take time and review.',
#       'textOriginal': "Thank you for the (for me) update. Understanding which site does what has helped me a lot!\nIt's been nice to take time and review.",
#       'authorDisplayName': '@haint7709',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/vPsC8Sb_ONZiw2im9KoEXcgn1M9H1hnyrJ3SaftcW_jVmkL0y4dXRv2CWJA-ZRU7xxZKaibx7w=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@haint7709',
#       'authorChannelId': {'value': 'UCdUxoirwasV5oxGDmP5VbOw'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2025-02-02T14:02:35Z',
#       'updatedAt': '2025-02-02T14:02:35Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'E-36mggtmgx0auXbt9iGrlerKn8',
#    'id': 'UgyRVNpLuZt6jWLEgw54AaABAg',
#    'snippet': {'channelId': 'UC8butISFwT-Wl7EV0hUK0BQ',
#     'videoId': 'R4v_7hh4Yys',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'XhsKSYVYUhFwGHn1kL0VVmuYcG4',
#      'id': 'UgyRVNpLuZt6jWLEgw54AaABAg',
#      'snippet': {'channelId': 'UC8butISFwT-Wl7EV0hUK0BQ',
#       'videoId': 'R4v_7hh4Yys',
#       'textDisplay': '2/4/25 Viewing; very good tutorial with added information. Love it!',
#       'textOriginal': '2/4/25 Viewing; very good tutorial with added information. Love it!',
#       'authorDisplayName': '@thomasarillotta6518',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_mEivGroXdYpdWrAskNwhEBKpwHRjL7uWmZvaB8pC1Z9T4=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@thomasarillotta6518',
#       'authorChannelId': {'value': 'UCNCOBua-jvl0NMgaKTgwZQg'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2025-02-04T14:32:43Z',
#       'updatedAt': '2025-02-04T14:32:43Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': '9Q10-cbGwgCaSHgp_ii_gnz21yM',
#    'id': 'UgzJbMJxIFIYVYYo7eJ4AaABAg',
#    'snippet': {'channelId': 'UC8butISFwT-Wl7EV0hUK0BQ',
#     'videoId': 'R4v_7hh4Yys',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'OP8X1h9CVJkWt0LPCmZMG3wCKhE',
#      'id': 'UgzJbMJxIFIYVYYo7eJ4AaABAg',
#      'snippet': {'channelId': 'UC8butISFwT-Wl7EV0hUK0BQ',
#       'videoId': 'R4v_7hh4Yys',
#       'textDisplay': 'Great. Your video is clear, well explained and well thought out. Thank you. Though I know to code and have also written  a website in html, I am starting a new website and figured it is time I actually use wordpress. I am doing a patreon integration that works with wordpress and was debating between using their REST API or maybe just finally getting set up with wordpress. I have worried how it might go as I wonder how much customization I will lose, but either way I think it is time I learn wordpress.',
#       'textOriginal': 'Great. Your video is clear, well explained and well thought out. Thank you. Though I know to code and have also written  a website in html, I am starting a new website and figured it is time I actually use wordpress. I am doing a patreon integration that works with wordpress and was debating between using their REST API or maybe just finally getting set up with wordpress. I have worried how it might go as I wonder how much customization I will lose, but either way I think it is time I learn wordpress.',
#       'authorDisplayName': '@Iliketoflystuff',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_lPAu5LcUW1h_9K92DDPIFAt7oKeKn1gaScOAfzdeLy0FyHMrhcwYmEo-u21qNz3kJRkA=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@Iliketoflystuff',
#       'authorChannelId': {'value': 'UC_0ZQiLG1mqc_ihibZdmLag'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 2,
#       'publishedAt': '2025-01-25T00:50:27Z',
#       'updatedAt': '2025-01-25T00:50:27Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': '8fGNFC4-LKkrGUEPv9OVSQHNG5c',
#    'id': 'Ugw0UPwcwJFMVSek48B4AaABAg',
#    'snippet': {'channelId': 'UC8butISFwT-Wl7EV0hUK0BQ',
#     'videoId': 'R4v_7hh4Yys',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'ciCHKlQ3PImf7U73Z15RCOCzeU4',
#      'id': 'Ugw0UPwcwJFMVSek48B4AaABAg',
#      'snippet': {'channelId': 'UC8butISFwT-Wl7EV0hUK0BQ',
#       'videoId': 'R4v_7hh4Yys',
#       'textDisplay': 'The FCC GOAT! Thanks for this forreal.',
#       'textOriginal': 'The FCC GOAT! Thanks for this forreal.',
#       'authorDisplayName': '@nelsoncruz-os7nz',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_mkLO97kTQBhD1y6_12_RwCBlZbvm0lFWC1fm-6j2EAW9Vj9t7ftMX_By3gz5Ppz7-oIQ=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@nelsoncruz-os7nz',
#       'authorChannelId': {'value': 'UCT09DRanoTmO2Ady2YU6CEg'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2025-01-31T16:14:55Z',
#       'updatedAt': '2025-01-31T16:14:55Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'nhhTtk5RJfR8YpRwi2eN13KSS64',
#    'id': 'Ugx9Yir-S-kmpuCwrVZ4AaABAg',
#    'snippet': {'channelId': 'UC8butISFwT-Wl7EV0hUK0BQ',
#     'videoId': 'R4v_7hh4Yys',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'eoYXQifruWk8CazDU85w0dZTtls',
#      'id': 'Ugx9Yir-S-kmpuCwrVZ4AaABAg',
#      'snippet': {'channelId': 'UC8butISFwT-Wl7EV0hUK0BQ',
#       'videoId': 'R4v_7hh4Yys',
#       'textDisplay': '👋Hello from South Africa 🎉',
#       'textOriginal': '👋Hello from South Africa 🎉',
#       'authorDisplayName': '@ronicataitia5824',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_l3fg__qadiYbyHC_DSjGbRuDeEzVMSEI8Lp4xPKk77tS3F=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@ronicataitia5824',
#       'authorChannelId': {'value': 'UCBHhtWgPjbCr2Euc2Ay1vZw'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 6,
#       'publishedAt': '2025-01-21T15:50:50Z',
#       'updatedAt': '2025-01-21T15:50:50Z'}},
#     'canReply': True,
#     'totalReplyCount': 1,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'kiZ9I_K65nr961TQNhK2x5PsozY',
#    'id': 'UgyQ6DB4ogYbf7b0BqZ4AaABAg',
#    'snippet': {'channelId': 'UC8butISFwT-Wl7EV0hUK0BQ',
#     'videoId': 'R4v_7hh4Yys',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'uBNBfn_iNOQaDBr-dHRdUKgIOzk',
#      'id': 'UgyQ6DB4ogYbf7b0BqZ4AaABAg',
#      'snippet': {'channelId': 'UC8butISFwT-Wl7EV0hUK0BQ',
#       'videoId': 'R4v_7hh4Yys',
#       'textDisplay': 'Right now when i needed it ❤',
#       'textOriginal': 'Right now when i needed it ❤',
#       'authorDisplayName': '@jakubfrei3757',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_mwqrTh6wQyuqWZXyaF9R5rQNueW-DmYmjQeopSSBu1_go=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@jakubfrei3757',
#       'authorChannelId': {'value': 'UCRw5yAZKi2JlI66GTZ3kUNA'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 2,
#       'publishedAt': '2025-01-21T15:03:59Z',
#       'updatedAt': '2025-01-21T15:03:59Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'A4jyGKfuBvenYPinLQ53Kb0Cu1A',
#    'id': 'UgzMYzDqnog7pSZ2Mrt4AaABAg',
#    'snippet': {'channelId': 'UC8butISFwT-Wl7EV0hUK0BQ',
#     'videoId': 'R4v_7hh4Yys',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '4JnvuoCVBtZQrDoZP16OpG4du90',
#      'id': 'UgzMYzDqnog7pSZ2Mrt4AaABAg',
#      'snippet': {'channelId': 'UC8butISFwT-Wl7EV0hUK0BQ',
#       'videoId': 'R4v_7hh4Yys',
#       'textDisplay': 'Thank you for the tutorial. Can this work for an e-commerce site?',
#       'textOriginal': 'Thank you for the tutorial. Can this work for an e-commerce site?',
#       'authorDisplayName': '@optimalhealingcanada',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/DhJNt2KhfnuMTxrAHX-0EHQYz6vyelRqom05OojulZeQOxzbSJ07otBLtHW1P9vTPRSPYX4c=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@optimalhealingcanada',
#       'authorChannelId': {'value': 'UC-looVys-4TdSCCxuS-wGiw'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2025-02-07T02:05:55Z',
#       'updatedAt': '2025-02-07T02:05:55Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'mqhIWI1xvhy-0qQyRrm8Ft8Mbz4',
#    'id': 'UgwxhYK73ys9xCIq7uh4AaABAg',
#    'snippet': {'channelId': 'UC8butISFwT-Wl7EV0hUK0BQ',
#     'videoId': 'R4v_7hh4Yys',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'AuJPnoZZD_wcdzuo9l7TwD5GeuI',
#      'id': 'UgwxhYK73ys9xCIq7uh4AaABAg',
#      'snippet': {'channelId': 'UC8butISFwT-Wl7EV0hUK0BQ',
#       'videoId': 'R4v_7hh4Yys',
#       'textDisplay': 'I wish you guys would teach custom WordPress development with code. Very hard to find great courses on that',
#       'textOriginal': 'I wish you guys would teach custom WordPress development with code. Very hard to find great courses on that',
#       'authorDisplayName': '@AGuy-x3d',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_nHNmhgK4mtwlkvbYzWQNsHe7dvV4nJKisK6SmVW8O7u9Pa8T0cWxyinae9f8_eisKzEw=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@AGuy-x3d',
#       'authorChannelId': {'value': 'UCtLOaHriWKK4596Ox6pxWBA'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 26,
#       'publishedAt': '2025-01-21T15:07:51Z',
#       'updatedAt': '2025-01-21T15:07:51Z'}},
#     'canReply': True,
#     'totalReplyCount': 4,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': '1D6JmoP2l_j56snlq4aMdMff8Qs',
#    'id': 'Ugz5TmEpEKm-cYCv58R4AaABAg',
#    'snippet': {'channelId': 'UC8butISFwT-Wl7EV0hUK0BQ',
#     'videoId': 'R4v_7hh4Yys',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'OFsk00tWfWuTleMzgsiiVkr-FmY',
#      'id': 'Ugz5TmEpEKm-cYCv58R4AaABAg',
#      'snippet': {'channelId': 'UC8butISFwT-Wl7EV0hUK0BQ',
#       'videoId': 'R4v_7hh4Yys',
#       'textDisplay': 'Thank you so much for this.',
#       'textOriginal': 'Thank you so much for this.',
#       'authorDisplayName': '@alisajadahmadi978',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_lzSzIh56PdVBZTLo3nCQUESWTpvQ8tSJ-WtsBUYOn1tbA=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@alisajadahmadi978',
#       'authorChannelId': {'value': 'UCyFE3W69TmbxSzJuMjj3GHw'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2025-01-27T03:31:50Z',
#       'updatedAt': '2025-01-27T03:31:50Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'A3WPKFFCYQPg_dNztQAEsaKuq7w',
#    'id': 'Ugw-gyPU_v7oVCO2ahV4AaABAg',
#    'snippet': {'channelId': 'UC8butISFwT-Wl7EV0hUK0BQ',
#     'videoId': 'R4v_7hh4Yys',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '-Aie-7dpBP-HIwTpEOjZVpfN-q0',
#      'id': 'Ugw-gyPU_v7oVCO2ahV4AaABAg',
#      'snippet': {'channelId': 'UC8butISFwT-Wl7EV0hUK0BQ',
#       'videoId': 'R4v_7hh4Yys',
#       'textDisplay': 'Thanks a lot❤',
#       'textOriginal': 'Thanks a lot❤',
#       'authorDisplayName': '@OmarAssrour-hz4cl',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_noTn5R62t8CWUZjhQ-xGduzMUZogFthqniMOcRODwOpkuKXBfW9JT96sWLZe3gs2nANQ=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@OmarAssrour-hz4cl',
#       'authorChannelId': {'value': 'UCY0OCE1U3i2qGfhCz1AFpTA'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2025-01-28T18:49:44Z',
#       'updatedAt': '2025-01-28T18:49:44Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'xYESNmeSaoW3pJn_qecuoCqTqc8',
#    'id': 'UgwhhVookb-r71sa1RV4AaABAg',
#    'snippet': {'channelId': 'UC8butISFwT-Wl7EV0hUK0BQ',
#     'videoId': 'R4v_7hh4Yys',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'nJaKi59DQ1gUH-9OFiHFE90i3rQ',
#      'id': 'UgwhhVookb-r71sa1RV4AaABAg',
#      'snippet': {'channelId': 'UC8butISFwT-Wl7EV0hUK0BQ',
#       'videoId': 'R4v_7hh4Yys',
#       'textDisplay': 'Great ❤❤❤',
#       'textOriginal': 'Great ❤❤❤',
#       'authorDisplayName': '@azharalibhutto1209',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/MsYnmZEPGAJImW4TEs_vOR7Q4Gx4Klif6KYGuZqvjAw_ZjImyBk_eZ2StsIBLyWhpx3gtLftvQ=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@azharalibhutto1209',
#       'authorChannelId': {'value': 'UCRB5vgk9PzcxFoagCYf_2Cw'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 1,
#       'publishedAt': '2025-01-22T01:47:30Z',
#       'updatedAt': '2025-01-22T01:47:30Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'sLaE9RVPbiEV0s2sXHb08HzqKfY',
#    'id': 'UgxyoRkEuHwRrP0wTQN4AaABAg',
#    'snippet': {'channelId': 'UC8butISFwT-Wl7EV0hUK0BQ',
#     'videoId': 'R4v_7hh4Yys',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '__5LG3yN3jV1fCEbTaVdpR7aFBY',
#      'id': 'UgxyoRkEuHwRrP0wTQN4AaABAg',
#      'snippet': {'channelId': 'UC8butISFwT-Wl7EV0hUK0BQ',
#       'videoId': 'R4v_7hh4Yys',
#       'textDisplay': 'Man it&#39;s really been a while since beau made a wordpress tutorial',
#       'textOriginal': "Man it's really been a while since beau made a wordpress tutorial",
#       'authorDisplayName': '@justindouglas3659',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/EMoDFxlie0BFM9_KlSGmSOEZ24PVI1GM0I6W_QQeCYRH0esQaeQ1cnj8GC6BaPFI-_tH4lLv4Q=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@justindouglas3659',
#       'authorChannelId': {'value': 'UCpQWVOCpDcbutf7jrzCte6A'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2025-01-21T14:59:49Z',
#       'updatedAt': '2025-01-21T14:59:49Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'Io9J1bf4qNjvDPzCoUACB8HG-X0',
#    'id': 'Ugwuow6rGtuQvcHZ7Fd4AaABAg',
#    'snippet': {'channelId': 'UC8butISFwT-Wl7EV0hUK0BQ',
#     'videoId': 'R4v_7hh4Yys',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'MZL7tg-sm8qqMfFnPff8h-SUcXs',
#      'id': 'Ugwuow6rGtuQvcHZ7Fd4AaABAg',
#      'snippet': {'channelId': 'UC8butISFwT-Wl7EV0hUK0BQ',
#       'videoId': 'R4v_7hh4Yys',
#       'textDisplay': 'At last a video on word press😂❤',
#       'textOriginal': 'At last a video on word press😂❤',
#       'authorDisplayName': '@HamzaAli-c8v8q',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/BR-YhAKBSH9xjql1ku8oNZjlcbgJ87Bdn4BsvVJ3gkBQfGhE2RuZ00CYaa0vAADzrAER7WcP1A=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@HamzaAli-c8v8q',
#       'authorChannelId': {'value': 'UCplC-eDvkpRMn83ktwmNtIA'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 1,
#       'publishedAt': '2025-01-21T15:00:27Z',
#       'updatedAt': '2025-01-21T15:00:27Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'u1MuObDLI8uwYJuKR3TPSItmlM4',
#    'id': 'UgzsP1IvQR4DiJsd06R4AaABAg',
#    'snippet': {'channelId': 'UC8butISFwT-Wl7EV0hUK0BQ',
#     'videoId': 'R4v_7hh4Yys',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'DN8H686UHOCHRCeyWYi-JAv1LRQ',
#      'id': 'UgzsP1IvQR4DiJsd06R4AaABAg',
#      'snippet': {'channelId': 'UC8butISFwT-Wl7EV0hUK0BQ',
#       'videoId': 'R4v_7hh4Yys',
#       'textDisplay': 'Thank you',
#       'textOriginal': 'Thank you',
#       'authorDisplayName': '@sonamuhialdeen7866',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_mumIw42b9bHo19jXzQnWI246GzOpkb-XiMda2P8mE=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@sonamuhialdeen7866',
#       'authorChannelId': {'value': 'UCXFVHseVUuN2cpnhQvGGnHw'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2025-01-26T13:17:01Z',
#       'updatedAt': '2025-01-26T13:17:01Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'j4UQXiIzWpoyvpwt5v8oRwJSuSA',
#    'id': 'Ugz1gO7kn4guDZXfwrl4AaABAg',
#    'snippet': {'channelId': 'UC8butISFwT-Wl7EV0hUK0BQ',
#     'videoId': 'R4v_7hh4Yys',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'kzjYBeeCLUs7NXJi-sV-d2BKgkk',
#      'id': 'Ugz1gO7kn4guDZXfwrl4AaABAg',
#      'snippet': {'channelId': 'UC8butISFwT-Wl7EV0hUK0BQ',
#       'videoId': 'R4v_7hh4Yys',
#       'textDisplay': 'fyi Astra starter templates doesn&#39;t seem to work at all, it&#39;s just blank',
#       'textOriginal': "fyi Astra starter templates doesn't seem to work at all, it's just blank",
#       'authorDisplayName': '@Jscodin',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_ktf9w-_Y-Ykk2WaCOrvRvto-DqwRfZrCwkWm-etOgO-lhcHcpTYkUtyPAuK6d42C4TAw=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@Jscodin',
#       'authorChannelId': {'value': 'UCQQrAxp4AZiSxphg3Jl5TTA'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 3,
#       'publishedAt': '2025-01-31T12:55:53Z',
#       'updatedAt': '2025-01-31T12:55:53Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'EVQGwcZXk-USRIPmngB8V45DQ1s',
#    'id': 'UgyWhUV3gEmkc70f41B4AaABAg',
#    'snippet': {'channelId': 'UC8butISFwT-Wl7EV0hUK0BQ',
#     'videoId': 'R4v_7hh4Yys',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'd5iE7crq5uRmIUW-BOn2s04b564',
#      'id': 'UgyWhUV3gEmkc70f41B4AaABAg',
#      'snippet': {'channelId': 'UC8butISFwT-Wl7EV0hUK0BQ',
#       'videoId': 'R4v_7hh4Yys',
#       'textDisplay': 'I like this video tutorial but wish you had time codes for specific areas!  Also, it seems Elementor is pretty demanding on upgrade to use things.  I can&#39;t seem to edit the header or footer since creating the intimal template',
#       'textOriginal': "I like this video tutorial but wish you had time codes for specific areas!  Also, it seems Elementor is pretty demanding on upgrade to use things.  I can't seem to edit the header or footer since creating the intimal template",
#       'authorDisplayName': '@WhereNerdyisCool',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_lyoXE9C2Pydwq1Hf-P4JTKpAKubb_mk1LXDLNn5s8iEzg=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@WhereNerdyisCool',
#       'authorChannelId': {'value': 'UCUVNmNDvV_C-MwbD8CmtOcA'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2025-01-22T19:35:52Z',
#       'updatedAt': '2025-01-23T01:25:19Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'a3UpzVa-aoIGRxeWrW4a1FL-mWI',
#    'id': 'Ugy-xhM8pRe7Xi0EZgd4AaABAg',
#    'snippet': {'channelId': 'UC8butISFwT-Wl7EV0hUK0BQ',
#     'videoId': 'R4v_7hh4Yys',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'XXOOKJtqnmYIQgXn6j0DKTe0tG4',
#      'id': 'Ugy-xhM8pRe7Xi0EZgd4AaABAg',
#      'snippet': {'channelId': 'UC8butISFwT-Wl7EV0hUK0BQ',
#       'videoId': 'R4v_7hh4Yys',
#       'textDisplay': 'the &quot;starter template&quot; button in astra did not work for me, my workaround was installing &quot;starter templates&quot; plugin manually. Not sure if this is proper practice but it seems to have worked for me.',
#       'textOriginal': 'the "starter template" button in astra did not work for me, my workaround was installing "starter templates" plugin manually. Not sure if this is proper practice but it seems to have worked for me.',
#       'authorDisplayName': '@KEVKONG360',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_k19Kb8ho7gKkLQOfnQaNXOQHrR3aqtb_ysWNrU0ps=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@KEVKONG360',
#       'authorChannelId': {'value': 'UCTzzCvL_yc9uKEyk5eXNBog'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 3,
#       'publishedAt': '2025-01-28T21:33:33Z',
#       'updatedAt': '2025-01-28T21:33:33Z'}},
#     'canReply': True,
#     'totalReplyCount': 2,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'y5-1MPxueeHIdGXt-oKUaxb5OaE',
#    'id': 'UgxttZ5_71WKsrW8pIN4AaABAg',
#    'snippet': {'channelId': 'UC8butISFwT-Wl7EV0hUK0BQ',
#     'videoId': 'R4v_7hh4Yys',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'bqegkEC7UANKvtQeJdJZ6R54wH4',
#      'id': 'UgxttZ5_71WKsrW8pIN4AaABAg',
#      'snippet': {'channelId': 'UC8butISFwT-Wl7EV0hUK0BQ',
#       'videoId': 'R4v_7hh4Yys',
#       'textDisplay': 'Thanks!!!!!!!',
#       'textOriginal': 'Thanks!!!!!!!',
#       'authorDisplayName': '@rogergm62',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/9lx79EvreG9hEHsY0Km95CJnc0rrkTbxNs6APa1trrxA3ZEuVfu__W1kqYC4wZOdLrqSymYB=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@rogergm62',
#       'authorChannelId': {'value': 'UCQukNl5unz8Dc3nVT6p3jKw'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2025-01-21T22:45:45Z',
#       'updatedAt': '2025-01-21T22:45:45Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'dKD9jug3cmkSAXDRs0mlYAMM1Nw',
#    'id': 'UgyHGFuSi-ieyYWefph4AaABAg',
#    'snippet': {'channelId': 'UC8butISFwT-Wl7EV0hUK0BQ',
#     'videoId': 'R4v_7hh4Yys',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'Gi8Xa0cR8dWPfDOQ8PGmG6psN1I',
#      'id': 'UgyHGFuSi-ieyYWefph4AaABAg',
#      'snippet': {'channelId': 'UC8butISFwT-Wl7EV0hUK0BQ',
#       'videoId': 'R4v_7hh4Yys',
#       'textDisplay': 'What about local setup, then moving it to the internet?',
#       'textOriginal': 'What about local setup, then moving it to the internet?',
#       'authorDisplayName': '@cbbcbb6803',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_mlMkUOWChooPnCDweR8xBN8MB3Z0ZrlCHaGn0b6DI=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@cbbcbb6803',
#       'authorChannelId': {'value': 'UCt6iSKYUCEeVyIxc-TPA5gg'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 1,
#       'publishedAt': '2025-01-22T04:09:21Z',
#       'updatedAt': '2025-01-22T04:09:21Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'OjBT2bdMONr7PB4VOd-7UY59MYQ',
#    'id': 'UgwSilt4hofebnNkyeR4AaABAg',
#    'snippet': {'channelId': 'UC8butISFwT-Wl7EV0hUK0BQ',
#     'videoId': 'R4v_7hh4Yys',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '128gC2E9yN68Ys3nNm_1QWQ0HRg',
#      'id': 'UgwSilt4hofebnNkyeR4AaABAg',
#      'snippet': {'channelId': 'UC8butISFwT-Wl7EV0hUK0BQ',
#       'videoId': 'R4v_7hh4Yys',
#       'textDisplay': 'good video',
#       'textOriginal': 'good video',
#       'authorDisplayName': '@visualmodo',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/CJ_FeVNHlopGY10xO50egDs25tn0L7MOjDYZLFhjiaaqfcashGO7PNa-elEft_oGvM-D9po_9Q=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@visualmodo',
#       'authorChannelId': {'value': 'UCsNkuVj19wfclwicQ4DgAUw'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2025-01-21T23:48:19Z',
#       'updatedAt': '2025-01-21T23:48:19Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'LU0RLoKCzM7mtJAP63pS-gpz-bk',
#    'id': 'Ugx46h7B8nHux5nEh0p4AaABAg',
#    'snippet': {'channelId': 'UC8butISFwT-Wl7EV0hUK0BQ',
#     'videoId': 'R4v_7hh4Yys',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'YXcd2Zby6ACCJepUN3E5x5iLMVU',
#      'id': 'Ugx46h7B8nHux5nEh0p4AaABAg',
#      'snippet': {'channelId': 'UC8butISFwT-Wl7EV0hUK0BQ',
#       'videoId': 'R4v_7hh4Yys',
#       'textDisplay': 'thanks.',
#       'textOriginal': 'thanks.',
#       'authorDisplayName': '@IsNoble_platform',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/XVEMpYO2veV7uI3hxuNFxltco2IWI5QSgPJergpM2pCxmAkB-Z4UI7LhxV8jGJYS6byeOnSz=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@IsNoble_platform',
#       'authorChannelId': {'value': 'UCXnjXU351Xnl0mCZbZEoOSg'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2025-01-23T08:05:40Z',
#       'updatedAt': '2025-01-23T08:05:40Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'co0_stsMOZLSqYQCIIKpoZcS86s',
#    'id': 'UgxElyjMRxPBovi0Rh14AaABAg',
#    'snippet': {'channelId': 'UC8butISFwT-Wl7EV0hUK0BQ',
#     'videoId': 'R4v_7hh4Yys',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'Ww43n6tTj7mL_yEv_U98c02DU_U',
#      'id': 'UgxElyjMRxPBovi0Rh14AaABAg',
#      'snippet': {'channelId': 'UC8butISFwT-Wl7EV0hUK0BQ',
#       'videoId': 'R4v_7hh4Yys',
#       'textDisplay': 'Here from Ghana',
#       'textOriginal': 'Here from Ghana',
#       'authorDisplayName': '@christabelmorganwright5830',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_lt4XOq3J2l6IlaUAwYSOyoml-xEbWtHSbzFz7i5tkEO_k=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@christabelmorganwright5830',
#       'authorChannelId': {'value': 'UCK42c6zU-wj6AEuZSRU-DzA'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2025-01-24T20:04:59Z',
#       'updatedAt': '2025-01-24T20:04:59Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'qA9N1YSaKxP0rutESXaEKkf30rU',
#    'id': 'UgyJV5RWjrmydTBWK3t4AaABAg',
#    'snippet': {'channelId': 'UC8butISFwT-Wl7EV0hUK0BQ',
#     'videoId': 'R4v_7hh4Yys',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'K5oZUP-XE_EXz5R7aExhC48SyjY',
#      'id': 'UgyJV5RWjrmydTBWK3t4AaABAg',
#      'snippet': {'channelId': 'UC8butISFwT-Wl7EV0hUK0BQ',
#       'videoId': 'R4v_7hh4Yys',
#       'textDisplay': 'My brother is setting up his business..and we were discussing this😂...mannnnn..what coincidence',
#       'textOriginal': 'My brother is setting up his business..and we were discussing this😂...mannnnn..what coincidence',
#       'authorDisplayName': '@striker_9',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_nn2r27xgt-QLsA4NOafS588bIhGJEP80r8XEC4pJEMwtmsmIosL5hG9gzQ2AyEbG8G0A=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@striker_9',
#       'authorChannelId': {'value': 'UCqAMVxU1Dpi9AB6YsTbhQRA'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2025-01-21T17:33:08Z',
#       'updatedAt': '2025-01-21T17:33:08Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}}]}

# %%
title = "How to Create a Website – WordPress Tutorial for Beginners 2025"
comments = [item["snippet"]["topLevelComment"]["snippet"]["textOriginal"] for item in vid["items"]]

# %%
comment_texts = [f"{i + 1}. {comment}" for i, comment in enumerate(comments)]
comment_texts
# Out:
# ['1. Good luck on creating your website!',
#  "2. Man you're actually reading my mind 😊",
#  "3. Thank you for the (for me) update. Understanding which site does what has helped me a lot!\nIt's been nice to take time and review.",
#  '4. 2/4/25 Viewing; very good tutorial with added information. Love it!',
#  '5. Great. Your video is clear, well explained and well thought out. Thank you. Though I know to code and have also written  a website in html, I am starting a new website and figured it is time I actually use wordpress. I am doing a patreon integration that works with wordpress and was debating between using their REST API or maybe just finally getting set up with wordpress. I have worried how it might go as I wonder how much customization I will lose, but either way I think it is time I learn wordpress.',
#  '6. The FCC GOAT! Thanks for this forreal.',
#  '7. 👋Hello from South Africa 🎉',
#  '8. Right now when i needed it ❤',
#  '9. Thank you for the tutorial. Can this work for an e-commerce site?',
#  '10. I wish you guys would teach custom WordPress development with code. Very hard to find great courses on that',
#  '11. Thank you so much for this.',
#  '12. Thanks a lot❤',
#  '13. Great ❤❤❤',
#  "14. Man it's really been a while since beau made a wordpress tutorial",
#  '15. At last a video on word press😂❤',
#  '16. Thank you',
#  "17. fyi Astra starter templates doesn't seem to work at all, it's just blank",
#  "18. I like this video tutorial but wish you had time codes for specific areas!  Also, it seems Elementor is pretty demanding on upgrade to use things.  I can't seem to edit the header or footer since creating the intimal template",
#  '19. the "starter template" button in astra did not work for me, my workaround was installing "starter templates" plugin manually. Not sure if this is proper practice but it seems to have worked for me.',
#  '20. Thanks!!!!!!!',
#  '21. What about local setup, then moving it to the internet?',
#  '22. good video',
#  '23. thanks.',
#  '24. Here from Ghana',
#  '25. My brother is setting up his business..and we were discussing this😂...mannnnn..what coincidence']

# %%
com = await analyze_comments(title, comment_texts)
com
# Out:
# len of comments: 25, len of labels: 25
# ['Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Negative',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Neutral',
#  'Positive',
#  'Positive',
#  'Negative',
#  'Negative',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Positive',
#  'Positive',
#  'Neutral',
#  'Neutral']

# %%
# List of region codes
region_codes = [
    "US",  # United States
    "GB",  # United Kingdom
    "CA",  # Canada
    "AU",  # Australia
    "IE",  # Ireland
    "NZ",  # New Zealand
    "ZA",  # South Africa
    "PH",  # Philippines
]

# List of YouTube video categories with unique IDs
video_categories = [
    {"category": "People & Blogs", "id": 22},
    {"category": "Entertainment", "id": 24},
    {"category": "Sports", "id": 17},
    {"category": "How-to & Style", "id": 26},
    {"category": "Autos & Vehicles", "id": 2},
    {"category": "Science & Technology", "id": 28},
    {"category": "News & Politics", "id": 25},
    {"category": "Music", "id": 10},
    {"category": "Pets & Animals", "id": 15},
    {"category": "Travel & Events", "id": 19},
    {"category": "Gaming", "id": 20},
    {"category": "Comedy", "id": 23},
    {"category": "Education", "id": 27},
    {"category": "Nonprofits & Activism", "id": 29},
]

# %%
def has_multiple_timestamps(comment):
    timestamps = re.findall(r'\d{1,2}(:\d{2}){1,3}', comment)
    return len(timestamps) > 3

# %%
def remove_links(comment):
    return re.sub(r'https?://\S+|www\.\S+', '', comment).strip()

# %%
videos = await fetch_videos_channel_pag('UC8butISFwT-Wl7EV0hUK0BQ', sort_by='viewCount')

# %%
len(videos)
# Out:
# 100

# %%
len({video["id"]['videoId'] for video in videos})
# Out:
# 100

# %%
video_ids = [video["id"]['videoId'] for video in videos]
video_with_none = [await fetch_video_details(video_id) for video_id in video_ids]
video_detailed = [video for video in video_with_none if video is not None]

# %%
len([vid for vid in video_detailed if int(vid['statistics']['commentCount']) >= 200])
# Out:
# 100

# %%
video_detailed[4]
# Out:
# {'kind': 'youtube#video',
#  'etag': 'RvnrVZquI5E9d7zMugmgiCvPeNY',
#  'id': 'vLnPwxZdW4Y',
#  'snippet': {'publishedAt': '2018-08-24T17:11:35Z',
#   'channelId': 'UC8butISFwT-Wl7EV0hUK0BQ',
#   'title': 'C++ Tutorial for Beginners - Full Course',
#   'description': "This course will give you a full introduction into all of the core concepts in C++. \n\nWant more from Mike? He's starting a coding RPG/Bootcamp - https://simulator.dev/\n\n⭐️ Contents ⭐\n⌨️ (0:00:00) Introduction\n⌨️ (0:01:38) Windows Installation\n⌨️ (0:04:54) Mac Installation\n⌨️ (0:08:44) Setup & Hello World\n⌨️ (0:12:29) Drawing a Shape\n⌨️ (0:19:55) Variables\n⌨️ (0:31:43) Data Types\n⌨️ (0:39:15) Working With Strings\n⌨️ (0:49:00) Working With Numbers\n⌨️ (0:59:41) Getting User Input\n⌨️ (1:05:32) Building a Calculator\n⌨️ (1:09:28) Building a Mad Libs\n⌨️ (1:13:45) Arrays\n⌨️ (1:20:03) Functions\n⌨️ (1:29:47) Return Statement\n⌨️ (1:35:22) If Statements\n⌨️ (1:47:15) If Statements (con't)\n⌨️ (1:55:58) Building a Better Calculator\n⌨️ (2:02:20) Switch Statements\n⌨️ (2:10:47) While Loops\n⌨️ (2:18:53) Building a Guessing Game\n⌨️ (2:29:18) For Loops\n⌨️ (2:38:32) Exponent Function\n⌨️ (2:45:21) 2d Arrays & Nested Loops\n⌨️ (2:54:55) Comments\n⌨️ (2:59:11) Pointers\n⌨️ (3:13:26) Classes & Objects\n⌨️ (3:25:40) Constructor Functions\n⌨️ (3:34:41) Object Functions\n⌨️ (3:41:43) Getters & Setters\n⌨️ (3:54:04) Inheritance\n\nCourse developed by Mike Dane. Check out his YouTube channel for more great programming courses: https://www.youtube.com/channel/UCvmINlrza7JHB1zkIOuXEbw\n\n🐦Follow Mike on Twitter: https://twitter.com/GiraffeAcademy\n\n🔗The Giraffe Academy website: http://www.giraffeacademy.com/\n\n⭐️Other full courses by Giraffe Academy on our channel ⭐️\n💻C: https://youtu.be/KJgsSFOSQv0\n💻Python: https://youtu.be/rfscVS0vtbw\n💻SQL: https://youtu.be/HXV3zeQKqGY\n💻Ruby: https://youtu.be/t_ispmWmdjY\n💻PHP: https://youtu.be/OK_JCtrrv-c\n\n--\n\nLearn to code for free and get a developer job: https://www.freecodecamp.org\n\nRead hundreds of articles on programming: https://medium.freecodecamp.org \n\n❤️ Support for this channel comes from our friends at Scrimba – the coding platform that's reinvented interactive learning: https://scrimba.com/freecodecamp",
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/vLnPwxZdW4Y/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/vLnPwxZdW4Y/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/vLnPwxZdW4Y/hqdefault.jpg',
#     'width': 480,
#     'height': 360},
#    'standard': {'url': 'https://i.ytimg.com/vi/vLnPwxZdW4Y/sddefault.jpg',
#     'width': 640,
#     'height': 480},
#    'maxres': {'url': 'https://i.ytimg.com/vi/vLnPwxZdW4Y/maxresdefault.jpg',
#     'width': 1280,
#     'height': 720}},
#   'channelTitle': 'freeCodeCamp.org',
#   'tags': ['C++ tutorial',
#    'C++ programming tutorial',
#    'learn C++',
#    'C++ language tutorial',
#    'learn C++ programming',
#    'learn C++ language',
#    'C++ tutorial for beginners',
#    'C++ programming tutorials',
#    'how to learn C++ language',
#    'how to learn C++',
#    'c++ programming',
#    'c++',
#    'c++ basics',
#    'c++ language',
#    'c++ tutorials',
#    'c++ for beginners',
#    'C++ Tutorials From Basic to Advance',
#    'c++ tutorials complete',
#    'c++ video tutorial',
#    'c++ programming tutorial complete',
#    'c++ programming tutorial for beginners',
#    'c plus plus'],
#   'categoryId': '27',
#   'liveBroadcastContent': 'none',
#   'defaultLanguage': 'en',
#   'localized': {'title': 'C++ Tutorial for Beginners - Full Course',
#    'description': "This course will give you a full introduction into all of the core concepts in C++. \n\nWant more from Mike? He's starting a coding RPG/Bootcamp - https://simulator.dev/\n\n⭐️ Contents ⭐\n⌨️ (0:00:00) Introduction\n⌨️ (0:01:38) Windows Installation\n⌨️ (0:04:54) Mac Installation\n⌨️ (0:08:44) Setup & Hello World\n⌨️ (0:12:29) Drawing a Shape\n⌨️ (0:19:55) Variables\n⌨️ (0:31:43) Data Types\n⌨️ (0:39:15) Working With Strings\n⌨️ (0:49:00) Working With Numbers\n⌨️ (0:59:41) Getting User Input\n⌨️ (1:05:32) Building a Calculator\n⌨️ (1:09:28) Building a Mad Libs\n⌨️ (1:13:45) Arrays\n⌨️ (1:20:03) Functions\n⌨️ (1:29:47) Return Statement\n⌨️ (1:35:22) If Statements\n⌨️ (1:47:15) If Statements (con't)\n⌨️ (1:55:58) Building a Better Calculator\n⌨️ (2:02:20) Switch Statements\n⌨️ (2:10:47) While Loops\n⌨️ (2:18:53) Building a Guessing Game\n⌨️ (2:29:18) For Loops\n⌨️ (2:38:32) Exponent Function\n⌨️ (2:45:21) 2d Arrays & Nested Loops\n⌨️ (2:54:55) Comments\n⌨️ (2:59:11) Pointers\n⌨️ (3:13:26) Classes & Objects\n⌨️ (3:25:40) Constructor Functions\n⌨️ (3:34:41) Object Functions\n⌨️ (3:41:43) Getters & Setters\n⌨️ (3:54:04) Inheritance\n\nCourse developed by Mike Dane. Check out his YouTube channel for more great programming courses: https://www.youtube.com/channel/UCvmINlrza7JHB1zkIOuXEbw\n\n🐦Follow Mike on Twitter: https://twitter.com/GiraffeAcademy\n\n🔗The Giraffe Academy website: http://www.giraffeacademy.com/\n\n⭐️Other full courses by Giraffe Academy on our channel ⭐️\n💻C: https://youtu.be/KJgsSFOSQv0\n💻Python: https://youtu.be/rfscVS0vtbw\n💻SQL: https://youtu.be/HXV3zeQKqGY\n💻Ruby: https://youtu.be/t_ispmWmdjY\n💻PHP: https://youtu.be/OK_JCtrrv-c\n\n--\n\nLearn to code for free and get a developer job: https://www.freecodecamp.org\n\nRead hundreds of articles on programming: https://medium.freecodecamp.org \n\n❤️ Support for this channel comes from our friends at Scrimba – the coding platform that's reinvented interactive learning: https://scrimba.com/freecodecamp"},
#   'defaultAudioLanguage': 'en'},
#  'contentDetails': {'duration': 'PT4H1M19S',
#   'dimension': '2d',
#   'definition': 'hd',
#   'caption': 'true',
#   'licensedContent': True,
#   'contentRating': {},
#   'projection': 'rectangular'},
#  'statistics': {'viewCount': '12776125',
#   'likeCount': '288680',
#   'favoriteCount': '0',
#   'commentCount': '11806'}}

# %%
len(video_detailed)
# Out:
# 100

# %%
video_details = video_detailed[50:]

# %%
async def sentiment_analysis_batch(region_code, cat_id, sort_by):
    try:
        if videos is None:
            print("Error fetching videos")
            return None
        failed_videos = []
        skip_com = 0
        if not video_details:
            print("No valid video details found")
            return None
        tot_vid_fetch = len(video_details)
        print(f'Total videos fetched: {tot_vid_fetch}')

        combined_output = []
        header = [
            "ComId", "Vid", "VideoTitle", "AuthorName", "AuthorCid", "Comment", "Sentiment",
            "LikeCount", "ReplyCount", "PublishedAt", "RegionCode", "CategoryId"
        ]

        tot_comments_fetch, tot_comments_analyzed = 0, 0
        request_count = 0
        start_time = time.time()
        for i, video in enumerate(video_details):
            failed_vid_appended = False
            try:
                video_id = video["id"]
                video_title = video["snippet"]["title"]
                com_cnt = int(video['statistics']['commentCount'])
                print(f'-------------------------- VIDEO NO. {i + 1} --------------------------')
                output_rows = []
                print(f'Fetching Comments for video {i + 1}. {video_title}')
                print(f'Video consist of {com_cnt} comments.')
                data_sources = []
                if com_cnt > 200:
                    data_sources.append(await fetch_comments_data(video_id, youtube_api_2, 100, "relevance"))
                    data_sources.append(await fetch_comments_data(video_id, youtube_api_3, 100, "time"))
                elif com_cnt > 100:
                    data_sources.append(await fetch_comments_data(video_id, youtube_api_2, 100, "relevance"))
                    remaining_comments = com_cnt - 100
                    data_sources.append(await fetch_comments_data(video_id, youtube_api_3, remaining_comments, "time"))
                else:
                    data_sources.append(await fetch_comments_data(video_id, youtube_api_2, com_cnt, "relevance"))
                if not data_sources:
                    print(f"No Comments Extracted for video {video_id}")
                    if not failed_vid_appended:
                        failed_videos.append(video)
                        failed_vid_appended = True
                    continue
                comments_fetched = sum(len(source["items"]) for source in data_sources if source and "items" in source)
                tot_comments_fetch += comments_fetched
                print(f'Comment Extracted: {comments_fetched}')
                for data in data_sources:
                    if not data or "items" not in data:
                        continue
                    comments = []
                    cur_com_skip = 0
                    for item in data["items"]:
                        comment_thread = item["snippet"]["topLevelComment"]["snippet"]
                        comment_text = comment_thread.get("textOriginal")
                        cleaned_comment = remove_links(comment_text)
                        if has_multiple_timestamps(comment_text):
                            skip_com += 1
                            cur_com_skip += 1
                            continue
                        comments.append({
                            "ComId": item.get("id"),
                            "Vid": video_id,
                            "VideoTitle": video_title,
                            "AuthorName": comment_thread.get("authorDisplayName"),
                            "AuthorCid": comment_thread.get("authorChannelId", {}).get("value", ""),
                            "Comment": cleaned_comment,
                            "LikeCount": comment_thread.get("likeCount", 0),
                            "ReplyCount": item["snippet"].get("totalReplyCount", 0),
                            "PublishedAt": comment_thread.get("publishedAt"),
                            "RegionCode": region_code,
                            "CategoryId": cat_id
                        })
                    print(f'Comments Skipped: {cur_com_skip}') if cur_com_skip > 0 else None
                    for i in range(0, len(comments), 25):
                        comment_batch = comments[i:i + 25]
                        comment_texts = [f"{i + 1}. {comment['Comment']}" for i, comment in enumerate(comment_batch)]
                        if request_count == 45:
                            elapsed_time = time.time() - start_time
                            sleep_time = max(0, 90 - elapsed_time)
                            sleep_time = sleep_time if sleep_time >= 10 else 10
                            print(f"Rate limit reached. Sleeping for {sleep_time} seconds.")
                            time.sleep(sleep_time)
                            request_count = 0
                            start_time = time.time()
                        try:
                          sentiment_labels = await analyze_comments(video_title, comment_texts)
                          request_count += 1
                          if sentiment_labels is None:
                              if not failed_vid_appended:
                                  failed_videos.append(video)
                                  failed_vid_appended = True
                              continue
                          for comment, sentiment in zip(comment_batch, sentiment_labels):
                              comment["Sentiment"] = sentiment
                              output_rows.append(comment)
                        except Exception as e:
                          print(f"Error analyzing comments: {e}")
                tot_comments_analyzed += len(output_rows)
                print(f'Comments analyzed: {len(output_rows)}')
                combined_output.extend(output_rows)
                print(f"Total comments fetched: {tot_comments_fetch}, Total comments analyzed: {tot_comments_analyzed}")
                try:
                  if output_rows:
                      csv_filename = f"sentiments-{region_code}-{cat_id}-{sort_by}-{video_id}.csv"
                      with open(csv_filename, mode="w", newline="", encoding="utf-8") as file:
                          writer = csv.DictWriter(file, fieldnames=header)
                          writer.writeheader()
                          writer.writerows(output_rows)
                      print(f"File created: {csv_filename}")
                except Exception as e:
                    print(f"Error writing to CSV: {e}")

            except Exception as e:
                print(f"Error processing video {video_id}: {e}")
                if not failed_vid_appended:
                    failed_videos.append(video)
                    failed_vid_appended = True
                continue
        try:
            if combined_output:
                csv_filename = f"combined_sentiments-{region_code}-{cat_id}-{sort_by}.csv"
                with open(csv_filename, mode="w", newline="", encoding="utf-8") as file:
                    writer = csv.DictWriter(file, fieldnames=header)
                    writer.writeheader()
                    writer.writerows(combined_output)
                print(f"Combined file created: {csv_filename}")
        except Exception as e:
            print(f"Error writing combined CSV: {e}")

        print(f"Sentiment analysis completed.")
        print(f"Total videos fetched: {tot_vid_fetch}")
        print(f"Total comments fetched: {tot_comments_fetch}")
        print(f"Total comments analyzed: {tot_comments_analyzed}")
        print(f"Total comments skipped: {skip_com}")
        if failed_videos:
            print(f"Failed videos: {len(failed_videos)}")
            # return failed_videos
            return None

    except Exception as e:
        print(f"Error in sentiment_analysis_batch: {e}")

# %%
sentiments = await sentiment_analysis_batch('freeCodeCamp', 27, 'viewCount')
sentiments
# Out:
# Total videos fetched: 50
# -------------------------- VIDEO NO. 1 --------------------------
# Fetching Comments for video 1. Docker Tutorial for Beginners - A Full DevOps Course on How to Run Applications in Containers
# Video consist of 1151 comments.
# Comment Extracted: 200
# Comments Skipped: 1
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 24
# Comments Skipped: 1
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 24
# Comments analyzed: 198
# Total comments fetched: 200, Total comments analyzed: 198
# File created: sentiments-freeCodeCamp-27-viewCount-fqMOX6JJhGo.csv
# -------------------------- VIDEO NO. 2 --------------------------
# Fetching Comments for video 2. Learn PostgreSQL Tutorial - Full Course for Beginners
# Video consist of 2086 comments.
# Comment Extracted: 200
# Comments Skipped: 3
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 22
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Comments analyzed: 197
# Total comments fetched: 400, Total comments analyzed: 395
# File created: sentiments-freeCodeCamp-27-viewCount-qw--VYLpxG4.csv
# -------------------------- VIDEO NO. 3 --------------------------
# Fetching Comments for video 3. Full React Course 2020 - Learn Fundamentals, Hooks, Context API, React Router, Custom Hooks
# Video consist of 2088 comments.
# Comment Extracted: 198
# Comments Skipped: 3
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 21
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 24
# Comments analyzed: 195
# Total comments fetched: 598, Total comments analyzed: 590
# File created: sentiments-freeCodeCamp-27-viewCount-4UZrsTqkcW4.csv
# -------------------------- VIDEO NO. 4 --------------------------
# Fetching Comments for video 4. Postman Beginner's Course - API Testing
# Video consist of 1216 comments.
# Comment Extracted: 200
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Comments analyzed: 200
# Total comments fetched: 798, Total comments analyzed: 790
# File created: sentiments-freeCodeCamp-27-viewCount-VywxIQ2ZXw4.csv
# -------------------------- VIDEO NO. 5 --------------------------
# Fetching Comments for video 5. The 50 Most Popular Linux & Terminal Commands - Full Course for Beginners
# Video consist of 1203 comments.
# Comment Extracted: 200
# Comments Skipped: 1
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 24
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Comments analyzed: 199
# Total comments fetched: 998, Total comments analyzed: 989
# File created: sentiments-freeCodeCamp-27-viewCount-ZtqBQ68cfJc.csv
# -------------------------- VIDEO NO. 6 --------------------------
# Fetching Comments for video 6. Data Structures and Algorithms in Python - Full Course for Beginners
# Video consist of 940 comments.
# Comment Extracted: 200
# Comments Skipped: 8
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 17
# Comments Skipped: 3
# Number of comments Analyzed: 25
# Rate limit reached. Sleeping for 18.3377628326416 seconds.
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 22
# Comments analyzed: 189
# Total comments fetched: 1198, Total comments analyzed: 1178
# File created: sentiments-freeCodeCamp-27-viewCount-pkYVOmU3MgA.csv
# -------------------------- VIDEO NO. 7 --------------------------
# Fetching Comments for video 7. Arduino Course for Beginners - Open-Source Electronics Platform
# Video consist of 1417 comments.
# Comment Extracted: 200
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Comments Skipped: 1
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 24
# Comments analyzed: 199
# Total comments fetched: 1398, Total comments analyzed: 1377
# File created: sentiments-freeCodeCamp-27-viewCount-zJ-LqeX_fLU.csv
# -------------------------- VIDEO NO. 8 --------------------------
# Fetching Comments for video 8. Linux Operating System - Crash Course for Beginners
# Video consist of 995 comments.
# Comment Extracted: 200
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Comments analyzed: 200
# Total comments fetched: 1598, Total comments analyzed: 1577
# File created: sentiments-freeCodeCamp-27-viewCount-ROjZy1WbCIA.csv
# -------------------------- VIDEO NO. 9 --------------------------
# Fetching Comments for video 9. Code a Discord Bot with Python - Host for Free in the Cloud
# Video consist of 3585 comments.
# Comment Extracted: 200
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Comments analyzed: 200
# Total comments fetched: 1798, Total comments analyzed: 1777
# File created: sentiments-freeCodeCamp-27-viewCount-SPTfmiYiuok.csv
# -------------------------- VIDEO NO. 10 --------------------------
# Fetching Comments for video 10. How to Put a Website Online: Template, Coding, Domain, Hosting, and DNS
# Video consist of 778 comments.
# Comment Extracted: 200
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Comments analyzed: 200
# Total comments fetched: 1998, Total comments analyzed: 1977
# File created: sentiments-freeCodeCamp-27-viewCount-NQP89ish9t8.csv
# -------------------------- VIDEO NO. 11 --------------------------
# Fetching Comments for video 11. Python API Development - Comprehensive Course for Beginners
# Video consist of 2318 comments.
# Comment Extracted: 200
# Comments Skipped: 4
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 21
# Comments Skipped: 3
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 22
# Comments analyzed: 193
# Total comments fetched: 2198, Total comments analyzed: 2170
# File created: sentiments-freeCodeCamp-27-viewCount-0sOvCWFmrtA.csv
# -------------------------- VIDEO NO. 12 --------------------------
# Fetching Comments for video 12. Full Stack Web Development for Beginners (Full Course on HTML, CSS, JavaScript, Node.js, MongoDB)
# Video consist of 1126 comments.
# Comment Extracted: 200
# Comments Skipped: 6
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Rate limit reached. Sleeping for 21.12440848350525 seconds.
# Number of comments Analyzed: 25
# Number of comments Analyzed: 19
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Error during sentiment analysis: Invalid operation: The `response.text` quick accessor requires the response to contain a valid `Part`, but none were returned. The candidate's [finish_reason](https://ai.google.dev/api/generate-content#finishreason) is 4. Meaning that the model was reciting from copyrighted material.
# Number of comments Analyzed: 25
# Comments analyzed: 169
# Total comments fetched: 2398, Total comments analyzed: 2339
# File created: sentiments-freeCodeCamp-27-viewCount-nu_pCVPKzTk.csv
# -------------------------- VIDEO NO. 13 --------------------------
# Fetching Comments for video 13. PyTorch for Deep Learning & Machine Learning – Full Course
# Video consist of 1344 comments.
# Comment Extracted: 200
# Comments Skipped: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Comments Skipped: 8
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 17
# Comments analyzed: 167
# Total comments fetched: 2598, Total comments analyzed: 2506
# File created: sentiments-freeCodeCamp-27-viewCount-V_xro1bcAuA.csv
# -------------------------- VIDEO NO. 14 --------------------------
# Fetching Comments for video 14. Introduction to Linux – Full Course for Beginners
# Video consist of 712 comments.
# Comment Extracted: 198
# Comments Skipped: 3
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 21
# Comments Skipped: 1
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 23
# Comments analyzed: 194
# Total comments fetched: 2796, Total comments analyzed: 2700
# File created: sentiments-freeCodeCamp-27-viewCount-sWbUDq4S6Y8.csv
# -------------------------- VIDEO NO. 15 --------------------------
# Fetching Comments for video 15. Linear Algebra - Full College Course
# Video consist of 1065 comments.
# Comment Extracted: 200
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Comments analyzed: 200
# Total comments fetched: 2996, Total comments analyzed: 2900
# File created: sentiments-freeCodeCamp-27-viewCount-JnTa9XtvmfI.csv
# -------------------------- VIDEO NO. 16 --------------------------
# Fetching Comments for video 16. Self-Driving Car with JavaScript Course – Neural Networks and Machine Learning
# Video consist of 1466 comments.
# Comment Extracted: 200
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Comments analyzed: 200
# Total comments fetched: 3196, Total comments analyzed: 3100
# File created: sentiments-freeCodeCamp-27-viewCount-Rs_rAxEsAvI.csv
# -------------------------- VIDEO NO. 17 --------------------------
# Fetching Comments for video 17. Object Oriented Programming with Python - Full Course for Beginners
# Video consist of 1261 comments.
# Comment Extracted: 200
# Comments Skipped: 1
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 24
# Comments Skipped: 1
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 24
# Comments analyzed: 198
# Total comments fetched: 3396, Total comments analyzed: 3298
# File created: sentiments-freeCodeCamp-27-viewCount-Ej_02ICOIgs.csv
# -------------------------- VIDEO NO. 18 --------------------------
# Fetching Comments for video 18. Google Sheets - Full Course
# Video consist of 468 comments.
# Comment Extracted: 200
# Comments Skipped: 4
# Rate limit reached. Sleeping for 14.57933759689331 seconds.
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 21
# Comments Skipped: 2
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 23
# Comments analyzed: 194
# Total comments fetched: 3596, Total comments analyzed: 3492
# File created: sentiments-freeCodeCamp-27-viewCount-N2opj8XzYBY.csv
# -------------------------- VIDEO NO. 19 --------------------------
# Fetching Comments for video 19. Learn Flask for Python - Full Tutorial
# Video consist of 1443 comments.
# Comment Extracted: 200
# Comments Skipped: 2
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 23
# Comments Skipped: 1
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 24
# Comments analyzed: 197
# Total comments fetched: 3796, Total comments analyzed: 3689
# File created: sentiments-freeCodeCamp-27-viewCount-Z1RJmh_OqeA.csv
# -------------------------- VIDEO NO. 20 --------------------------
# Fetching Comments for video 20. Precalculus Course
# Video consist of 1543 comments.
# Comment Extracted: 200
# Comments Skipped: 7
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 18
# Comments Skipped: 2
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 23
# Comments analyzed: 191
# Total comments fetched: 3996, Total comments analyzed: 3880
# File created: sentiments-freeCodeCamp-27-viewCount-eI4an8aSsgw.csv
# -------------------------- VIDEO NO. 21 --------------------------
# Fetching Comments for video 21. NestJs Course for Beginners - Create a REST API
# Video consist of 889 comments.
# Comment Extracted: 200
# Comments Skipped: 1
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 24
# Comments Skipped: 1
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 24
# Comments analyzed: 198
# Total comments fetched: 4196, Total comments analyzed: 4078
# File created: sentiments-freeCodeCamp-27-viewCount-GHTA143_b-s.csv
# -------------------------- VIDEO NO. 22 --------------------------
# Fetching Comments for video 22. Advanced Computer Vision with Python - Full Course
# Video consist of 1010 comments.
# Comment Extracted: 200
# Comments Skipped: 1
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 24
# Comments Skipped: 1
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 24
# Comments analyzed: 198
# Total comments fetched: 4396, Total comments analyzed: 4276
# File created: sentiments-freeCodeCamp-27-viewCount-01sAkU_NvOY.csv
# -------------------------- VIDEO NO. 23 --------------------------
# Fetching Comments for video 23. Machine Learning Course for Beginners
# Video consist of 1354 comments.
# Comment Extracted: 200
# Comments Skipped: 4
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 21
# Comments Skipped: 2
# Number of comments Analyzed: 25
# Rate limit reached. Sleeping for 10.043338060379028 seconds.
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 23
# Comments analyzed: 194
# Total comments fetched: 4596, Total comments analyzed: 4470
# File created: sentiments-freeCodeCamp-27-viewCount-NWONeJKn6kc.csv
# -------------------------- VIDEO NO. 24 --------------------------
# Fetching Comments for video 24. Kotlin Course - Tutorial for Beginners
# Video consist of 1221 comments.
# Comment Extracted: 200
# Comments Skipped: 1
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 24
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Comments analyzed: 199
# Total comments fetched: 4796, Total comments analyzed: 4669
# File created: sentiments-freeCodeCamp-27-viewCount-F9UC9DY-vIU.csv
# -------------------------- VIDEO NO. 25 --------------------------
# Fetching Comments for video 25. Git for Professionals Tutorial - Tools & Concepts for Mastering Version Control with Git
# Video consist of 495 comments.
# Comment Extracted: 200
# Comments Skipped: 1
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 24
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Comments analyzed: 199
# Total comments fetched: 4996, Total comments analyzed: 4868
# File created: sentiments-freeCodeCamp-27-viewCount-Uszj_k0DGsg.csv
# -------------------------- VIDEO NO. 26 --------------------------
# Fetching Comments for video 26. Algorithms Course - Graph Theory Tutorial from a Google Engineer
# Video consist of 761 comments.
# Comment Extracted: 200
# Comments Skipped: 5
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 20
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Comments analyzed: 195
# Total comments fetched: 5196, Total comments analyzed: 5063
# File created: sentiments-freeCodeCamp-27-viewCount-09_LlHjoEiY.csv
# -------------------------- VIDEO NO. 27 --------------------------
# Fetching Comments for video 27. Generative AI Full Course – Gemini Pro, OpenAI, Llama, Langchain, Pinecone, Vector Databases & More
# Video consist of 1786 comments.
# Comment Extracted: 200
# Comments Skipped: 7
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 18
# Comments Skipped: 2
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 23
# Comments analyzed: 191
# Total comments fetched: 5396, Total comments analyzed: 5254
# File created: sentiments-freeCodeCamp-27-viewCount-mEsleV16qdo.csv
# -------------------------- VIDEO NO. 28 --------------------------
# Fetching Comments for video 28. Web Scraping with Python - Beautiful Soup Crash Course
# Video consist of 1061 comments.
# Comment Extracted: 200
# Comments Skipped: 1
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 24
# Comments Skipped: 1
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 24
# Comments analyzed: 198
# Total comments fetched: 5596, Total comments analyzed: 5452
# File created: sentiments-freeCodeCamp-27-viewCount-XVv6mJpFOb0.csv
# -------------------------- VIDEO NO. 29 --------------------------
# Fetching Comments for video 29. Automate with Python – Full Course for Beginners
# Video consist of 359 comments.
# Comment Extracted: 200
# Comments Skipped: 5
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Rate limit reached. Sleeping for 13.702415704727173 seconds.
# Number of comments Analyzed: 25
# Number of comments Analyzed: 20
# Comments Skipped: 3
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Error decoding JSON response: Expecting value: line 1 column 2 (char 1)
# Raw output: ['Neutral', 'Neutral', 'Neutral', 'Positive', 'Neutral', 'Neutral', 'Positive', 'Negative', 'Neutral', 'Neutral', 'Negative', 'Negative', 'Neutral', 'Neutral', 'Neutral', 'Positive', 'Negative', 'Neutral', 'Negative', 'Neutral', 'Neutral', 'Positive', 'Positive', 'Neutral', 'Neutral']
# Number of comments Analyzed: 22
# Comments analyzed: 167
# Total comments fetched: 5796, Total comments analyzed: 5619
# File created: sentiments-freeCodeCamp-27-viewCount-PXMJ6FS7llk.csv
# -------------------------- VIDEO NO. 30 --------------------------
# Fetching Comments for video 30. Angular for Beginners Course [Full Front End Tutorial with TypeScript]
# Video consist of 1004 comments.
# Comment Extracted: 200
# Comments Skipped: 7
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 18
# Comments Skipped: 3
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 22
# Comments analyzed: 190
# Total comments fetched: 5996, Total comments analyzed: 5809
# File created: sentiments-freeCodeCamp-27-viewCount-3qBXWUpoPHo.csv
# -------------------------- VIDEO NO. 31 --------------------------
# Fetching Comments for video 31. Azure Administrator Certification (AZ-104) - Full Course to PASS the Exam
# Video consist of 831 comments.
# Comment Extracted: 200
# Comments Skipped: 4
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 21
# Comments Skipped: 1
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 24
# Comments analyzed: 195
# Total comments fetched: 6196, Total comments analyzed: 6004
# File created: sentiments-freeCodeCamp-27-viewCount-10PbGbTUSAg.csv
# -------------------------- VIDEO NO. 32 --------------------------
# Fetching Comments for video 32. Assembly Language Programming with ARM – Full Tutorial for Beginners
# Video consist of 968 comments.
# Comment Extracted: 200
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Comments Skipped: 1
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 24
# Comments analyzed: 199
# Total comments fetched: 6396, Total comments analyzed: 6203
# File created: sentiments-freeCodeCamp-27-viewCount-gfmRrPjnEw4.csv
# -------------------------- VIDEO NO. 33 --------------------------
# Fetching Comments for video 33. Learn ASP.NET Core MVC (.NET 6) - Full Course
# Video consist of 762 comments.
# Comment Extracted: 200
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Comments analyzed: 200
# Total comments fetched: 6596, Total comments analyzed: 6403
# File created: sentiments-freeCodeCamp-27-viewCount-hZ1DASYd9rk.csv
# -------------------------- VIDEO NO. 34 --------------------------
# Fetching Comments for video 34. Java Programming for Beginners – Full Course
# Video consist of 568 comments.
# Comment Extracted: 200
# Comments Skipped: 1
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 24
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Rate limit reached. Sleeping for 15.014223337173462 seconds.
# Number of comments Analyzed: 25
# Comments analyzed: 199
# Total comments fetched: 6796, Total comments analyzed: 6602
# File created: sentiments-freeCodeCamp-27-viewCount-A74TOX803D0.csv
# -------------------------- VIDEO NO. 35 --------------------------
# Fetching Comments for video 35. UML Diagrams Full Course (Unified Modeling Language)
# Video consist of 361 comments.
# Comment Extracted: 200
# Comments Skipped: 2
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 23
# Comments Skipped: 2
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 23
# Comments analyzed: 196
# Total comments fetched: 6996, Total comments analyzed: 6798
# File created: sentiments-freeCodeCamp-27-viewCount-WnMQ8HlmeXc.csv
# -------------------------- VIDEO NO. 36 --------------------------
# Fetching Comments for video 36. How To Make a Website With WordPress (Beginners Tutorial)
# Video consist of 651 comments.
# Comment Extracted: 198
# Comments Skipped: 1
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 23
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 24
# Comments analyzed: 197
# Total comments fetched: 7194, Total comments analyzed: 6995
# File created: sentiments-freeCodeCamp-27-viewCount-O79pJ7qXwoE.csv
# -------------------------- VIDEO NO. 37 --------------------------
# Fetching Comments for video 37. Data Analyst Bootcamp for Beginners (SQL, Tableau, Power BI, Python, Excel, Pandas, Projects, more)
# Video consist of 938 comments.
# Comment Extracted: 200
# Comments Skipped: 7
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 18
# Comments Skipped: 3
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 22
# Comments analyzed: 190
# Total comments fetched: 7394, Total comments analyzed: 7185
# File created: sentiments-freeCodeCamp-27-viewCount-PSNXoAs2FtQ.csv
# -------------------------- VIDEO NO. 38 --------------------------
# Fetching Comments for video 38. AWS Certified Cloud Practitioner Certification Course (CLF-C02) - Pass the Exam!
# Video consist of 1199 comments.
# Comment Extracted: 200
# Comments Skipped: 7
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 18
# Comments Skipped: 3
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 22
# Comments analyzed: 190
# Total comments fetched: 7594, Total comments analyzed: 7375
# File created: sentiments-freeCodeCamp-27-viewCount-NhDYbskXRgc.csv
# -------------------------- VIDEO NO. 39 --------------------------
# Fetching Comments for video 39. Bootstrap CSS Framework - Full Course for Beginners
# Video consist of 535 comments.
# Comment Extracted: 200
# Comments Skipped: 2
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 23
# Comments Skipped: 1
# Number of comments Analyzed: 25
# Error decoding JSON response: Expecting value: line 1 column 2 (char 1)
# Raw output: ['Neutral', 'Neutral', 'Positive', 'Neutral', 'Positive', 'Positive', 'Positive', 'Neutral', 'Neutral', 'Positive', 'Positive', 'Neutral', 'Negative', 'Negative', 'Negative', 'Neutral', 'Positive', 'Negative', 'Neutral', 'Positive', 'Neutral', 'Neutral', 'Neutral', 'Positive', 'Positive']
# Number of comments Analyzed: 25
# Number of comments Analyzed: 24
# Comments analyzed: 172
# Total comments fetched: 7794, Total comments analyzed: 7547
# File created: sentiments-freeCodeCamp-27-viewCount--qfEOE4vtxE.csv
# -------------------------- VIDEO NO. 40 --------------------------
# Fetching Comments for video 40. PySpark Tutorial
# Video consist of 554 comments.
# Comment Extracted: 198
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 24
# Rate limit reached. Sleeping for 10 seconds.
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 24
# Comments analyzed: 198
# Total comments fetched: 7992, Total comments analyzed: 7745
# File created: sentiments-freeCodeCamp-27-viewCount-_C8kWso4ne4.csv
# -------------------------- VIDEO NO. 41 --------------------------
# Fetching Comments for video 41. Database Systems - Cornell University Course (SQL, NoSQL, Large-Scale Data Analysis)
# Video consist of 538 comments.
# Comment Extracted: 200
# Comments Skipped: 3
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 22
# Comments Skipped: 1
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 24
# Comments analyzed: 196
# Total comments fetched: 8192, Total comments analyzed: 7941
# File created: sentiments-freeCodeCamp-27-viewCount-4cWkVbC2bNE.csv
# -------------------------- VIDEO NO. 42 --------------------------
# Fetching Comments for video 42. System Design for Beginners Course
# Video consist of 349 comments.
# Comment Extracted: 200
# Comments Skipped: 1
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 24
# Comments Skipped: 1
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 24
# Comments analyzed: 198
# Total comments fetched: 8392, Total comments analyzed: 8139
# File created: sentiments-freeCodeCamp-27-viewCount-m8Icp_Cid5o.csv
# -------------------------- VIDEO NO. 43 --------------------------
# Fetching Comments for video 43. Vue.js Course for Beginners [2021 Tutorial]
# Video consist of 500 comments.
# Comment Extracted: 200
# Comments Skipped: 1
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 24
# Comments Skipped: 1
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 24
# Comments analyzed: 198
# Total comments fetched: 8592, Total comments analyzed: 8337
# File created: sentiments-freeCodeCamp-27-viewCount-FXpIoQ_rT_c.csv
# -------------------------- VIDEO NO. 44 --------------------------
# Fetching Comments for video 44. How to Build an E-commerce Website with Django and Python
# Video consist of 560 comments.
# Comment Extracted: 200
# Comments Skipped: 2
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 23
# Comments Skipped: 1
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 24
# Comments analyzed: 197
# Total comments fetched: 8792, Total comments analyzed: 8534
# File created: sentiments-freeCodeCamp-27-viewCount-YZvRrldjf1Y.csv
# -------------------------- VIDEO NO. 45 --------------------------
# Fetching Comments for video 45. Graph Algorithms for Technical Interviews - Full Course
# Video consist of 738 comments.
# Comment Extracted: 200
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Comments Skipped: 1
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 24
# Comments analyzed: 199
# Total comments fetched: 8992, Total comments analyzed: 8733
# File created: sentiments-freeCodeCamp-27-viewCount-tWVWeAqZ0WU.csv
# -------------------------- VIDEO NO. 46 --------------------------
# Fetching Comments for video 46. Visual Studio Code Crash Course
# Video consist of 479 comments.
# Comment Extracted: 200
# Comments Skipped: 4
# Number of comments Analyzed: 25
# Rate limit reached. Sleeping for 10 seconds.
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 21
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Comments analyzed: 196
# Total comments fetched: 9192, Total comments analyzed: 8929
# File created: sentiments-freeCodeCamp-27-viewCount-WPqXP_kLzpo.csv
# -------------------------- VIDEO NO. 47 --------------------------
# Fetching Comments for video 47. Linux Server Course - System Configuration and Operation
# Video consist of 498 comments.
# Comment Extracted: 200
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Comments analyzed: 200
# Total comments fetched: 9392, Total comments analyzed: 9129
# File created: sentiments-freeCodeCamp-27-viewCount-WMy3OzvBWc0.csv
# -------------------------- VIDEO NO. 48 --------------------------
# Fetching Comments for video 48. Learn JavaScript by Building 7 Games - Full Course
# Video consist of 910 comments.
# Comment Extracted: 200
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Comments analyzed: 200
# Total comments fetched: 9592, Total comments analyzed: 9329
# File created: sentiments-freeCodeCamp-27-viewCount-ec8vSKJuZTk.csv
# -------------------------- VIDEO NO. 49 --------------------------
# Fetching Comments for video 49. JavaScript DOM Manipulation – Full Course for Beginners
# Video consist of 655 comments.
# Comment Extracted: 200
# Comments Skipped: 2
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 23
# Comments Skipped: 1
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 24
# Comments analyzed: 197
# Total comments fetched: 9792, Total comments analyzed: 9526
# File created: sentiments-freeCodeCamp-27-viewCount-5fb2aPlgoys.csv
# -------------------------- VIDEO NO. 50 --------------------------
# Fetching Comments for video 50. Learn TypeScript – Full Tutorial
# Video consist of 943 comments.
# Comment Extracted: 200
# Comments Skipped: 4
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 21
# Comments Skipped: 2
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 25
# Number of comments Analyzed: 23
# Comments analyzed: 194
# Total comments fetched: 9992, Total comments analyzed: 9720
# File created: sentiments-freeCodeCamp-27-viewCount-30LWjhZzg50.csv
# Combined file created: combined_sentiments-freeCodeCamp-27-viewCount.csv
# Sentiment analysis completed.
# Total videos fetched: 50
# Total comments fetched: 9992
# Total comments analyzed: 9720
# Total comments skipped: 197
# Failed videos: 3
